# %% [markdown]
# <a href="https://colab.research.google.com/github/foxyto-coder/practicaparcial/blob/main/ventas_analisis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análisis de Ventas de Tecnología
#
# Este notebook analiza los datos de ventas de productos tecnológicos durante el año 2023.

# %%
# Importar librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargar datos
# Reemplaza la URL con la de tu archivo raw en GitHub
url = 'https://raw.githubusercontent.com/foxyto-coder/practicaparcial/refs/heads/main/ventas_tecnologia.csv.csv'
df = pd.read_csv(url)
df.head()
# Out:
#             Mes  Laptops  Smartphones  Tablets  Auriculares  SmartTV
# 0    enero 2023       45          120       35           89       12
# 1  febrero 2023       38          145       42           95       15
# 2    marzo 2023       52          135       38          102       18
# 3    abril 2023       49          155       45          115       20
# 4     mayo 2023       55          160       48          125       22

# %%
# Crear gráfico de líneas para todas las categorías
plt.figure(figsize=(15, 8))
for columna in df.columns[1:]:  # Excluimos la columna 'Mes'
    plt.plot(df['Mes'], df[columna], marker='o', label=columna)

plt.title('Ventas de Productos Tecnológicos 2023')
plt.xlabel('Mes')
plt.ylabel('Unidades Vendidas')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Espacio para análisis adicional del alumno
#
# En esta sección puedes agregar tu propio código para análisis adicionales.

# %%
# prompt: CREA DATOS DESCRIPTIVOS Y QUE NO TIRE ERRRRRRORRRR

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Check if the URL is valid and the file exists
try:
    # Reemplaza la URL con la de tu archivo raw en GitHub
    url = 'https://raw.githubusercontent.com/foxyto-coder/practicaparcial/refs/heads/main/ventas_tecnologia.csv.csv'
    df = pd.read_csv(url)
    df.head()
except FileNotFoundError:
    print("Error: File not found at the specified URL.")
    # Handle the error appropriately, e.g., exit the program or use a default DataFrame
    exit() # Or create a dummy DataFrame
except Exception as e:
  print(f"An error occurred: {e}")
  exit()


# Check if the DataFrame is empty or if the necessary columns exist
if df.empty:
    print("Error: The DataFrame is empty.")
    exit() # Or create a dummy DataFrame

required_columns = ['Mes'] # Add other essential columns
if not all(col in df.columns for col in required_columns):
    print(f"Error: The DataFrame is missing required columns: {', '.join(set(required_columns) - set(df.columns))}")
    exit() # or create dummy data for those columns

# If the DataFrame is valid, proceed with the rest of the code
try:
  plt.figure(figsize=(15, 8))
  for columna in df.columns[1:]:  # Excluimos la columna 'Mes'
      plt.plot(df['Mes'], df[columna], marker='o', label=columna)

  plt.title('Ventas de Productos Tecnológicos 2023')
  plt.xlabel('Mes')
  plt.ylabel('Unidades Vendidas')
  plt.xticks(rotation=45)
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.show()
except Exception as e:
  print(f"An error occurred while plotting: {e}")


# Espacio para análisis adicional del alumno

# Example of descriptive statistics
if not df.empty: # Check that the DataFrame is not empty
    print("\nDescriptive Statistics:")
    print(df.describe())

    # Example of correlation matrix (if numerical columns exist)
    numerical_cols = df.select_dtypes(include=['number']).columns
    if len(numerical_cols) > 1:
      print("\nCorrelation Matrix:")
      print(df[numerical_cols].corr())
# Out:
# Descriptive Statistics:
#          Laptops  Smartphones    Tablets  Auriculares    SmartTV
# count  12.000000    12.000000  12.000000    12.000000  12.000000
# mean   61.166667   173.333333  51.833333   134.083333  24.583333
# std    16.196707    31.790031  10.684171    30.964667   8.039203
# min    38.000000   120.000000  35.000000    89.000000  12.000000
# 25%    51.250000   152.500000  44.250000   111.750000  19.500000
# 50%    59.000000   177.500000  53.000000   136.500000  24.500000
# 75%    66.250000   191.250000  58.500000   149.750000  28.500000
# max    95.000000   230.000000  70.000000   190.000000  40.000000
#
# Correlation Matrix:
#               Laptops  Smartphones   Tablets  Auriculares   SmartTV
# Laptops      1.000000     0.899273  0.907961     0.952880  0.971052
# Smartphones  0.899273     1.000000  0.994785     0.983711  0.959247
# Tablets      0.907961     0.994785  1.000000     0.988463  0.963328
# ...
